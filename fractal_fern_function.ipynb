# %%
# !pip install numpy
# !pip install matplotlib
# Out:
# ...
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/28/75/3b679b41713bb60e2e8f6e2f87be72c971c9e718b1c17b8f8749240ddca8/numpy-1.26.2-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.2 kB 330.3 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.2 kB 495.5 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.2 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 61.2/61.2 kB 326.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.5 MB 2.6 MB/s eta 0:00:06
#     --------------------------------------- 0.3/15.5 MB 3.8 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/15.5 MB 4.1 MB/s eta 0:00:04
#    - -------------------------------------- 0.7/15.5 MB 4.2 MB/s eta 0:00:04
# ...

# %%
# if r > 0.93: (x,y) -> (-0.15x + 0.28y, 0.26x + 0.24y + 0.44)
# if 0.86 < r <= 0.93: (x,y) -> (0.2x -0.26y, 0.23x + 0.22y + 1.6)
# if 0.01 < r <= 0.86: (x,y) -> (0.85x + 0.04y, -0.04x + 0.85y + 1.6)
# if r <= 0.01: (x,y) -> (0,0.16y)
# Atualizado!

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def fractal_fern(n):
  n = n
  x = 0
  y = 0
  xn = 0
  yn = 0
  x1 = []
  y1 = []

  for i in range(n):
    r = np.random.default_rng()
    r = r.random()

    if r > 0.93:
      xn = (-0.15*x + 0.28*y)
      yn = (0.26*x + 0.24*y + 0.44)

    elif 0.86 < r <= 0.93:
      xn = (0.2*x -0.26*y)
      yn = (0.23*x + 0.22*y + 1.6)

    elif  0.01 < r <= 0.86:
      xn = (0.85*x + 0.04*y)
      yn = (-0.04*x + 0.85*y + 1.6)

    else:
      xn = (0)
      yn = (0.16*y)

    x = xn
    y = yn
    x1.append(x)
    y1.append(y)

  return x1, y1

# %%
a = 35000

guardar = fractal_fern(a)
x0 = guardar[0]
y0 = guardar[1]

plt.scatter(x0, y0, color='g', s=1)
plt.show()
